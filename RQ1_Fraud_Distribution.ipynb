# %%
import os

print("Checking dataset path...\n")

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename)) 


# =========================================
# RQ1 - Fraud Distribution Analysis
# =========================================

import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv(
    "/kaggle/input/datasets/nelgiriyewithana/credit-card-fraud-detection-dataset-2023/creditcard_2023.csv"
)

print("Dataset Loaded Successfully")

print("\nShape:")
print(data.shape)

print("\nFirst 5 Rows:")
print(data.head())

# Fraud Distribution Table
rq1_table = data['Class'].value_counts()

print("\nFraud Distribution:")
print(rq1_table)

# Save table
rq1_table.to_csv("RQ1_Fraud_Distribution.csv")

# Plot Figure
plt.figure(figsize=(6,4))

data['Class'].value_counts().plot(kind='bar')

plt.title("Fraud vs Normal Transactions")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Count")

# Save figure
plt.savefig("RQ1_Fraud_Distribution.pdf")

plt.show()

print("\nRQ1 Completed Successfully")
# Out:
# Checking dataset path...
#
# /kaggle/input/notebooks/basmalaawad/credit-card-fraud-dataset/__results__.html
# /kaggle/input/notebooks/basmalaawad/credit-card-fraud-dataset/__notebook__.ipynb
# /kaggle/input/notebooks/basmalaawad/credit-card-fraud-dataset/__output__.json
# /kaggle/input/notebooks/basmalaawad/credit-card-fraud-dataset/custom.css
# /kaggle/input/notebooks/basmalaawad/credit-card-fraud-dataset/__results___files/__results___15_1.png
# /kaggle/input/notebooks/basmalaawad/credit-card-fraud-dataset/__results___files/__results___23_1.png
# /kaggle/input/datasets/nelgiriyewithana/credit-card-fraud-detection-dataset-2023/creditcard_2023.csv
# Dataset Loaded Successfully
#
# Shape:
# (568630, 31)
#
# First 5 Rows:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# ...
